# %% [markdown]
# # 02 — Train LightFM (MovieLens or sample)
# If you have MovieLens 100k downloaded, this will use it; otherwise it falls back to the synthetic sample.

# %%
import sys, os
sys.path.insert(0, os.path.abspath('..'))
sys.path.insert(0, os.path.abspath('../src'))

# %%
# !python ../scripts/train_lightfm.py

# %% [markdown]
# After running, check that `artifacts/lightfm_model.joblib` and `artifacts/lightfm_maps.json` exist.
