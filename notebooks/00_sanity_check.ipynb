# %% [markdown]
# # 00 — Sanity Check

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))       # add project root
sys.path.insert(0, os.path.abspath("../src"))   # (belt-and-suspenders)

# %%
import sys, platform
print(sys.version)
print(platform.platform())
# Out:
# 3.11.14 | packaged by conda-forge | (main, Oct 22 2025, 22:56:31) [Clang 19.1.7 ]
# macOS-26.0.1-arm64-arm-64bit

# %%
import pandas as pd, numpy as np
import sklearn
print(pd.__version__, np.__version__, sklearn.__version__)
# Out:
# 2.3.3 2.3.4 1.7.2

# %%
from src.models.metrics import precision_at_k, recall_at_k, ndcg_at_k
y_true=[1,2,3]; y_pred=[3,4,5,1]
print('precision@3', precision_at_k(y_true, y_pred, 3))
print('recall@3', recall_at_k(y_true, y_pred, 3))
print('ndcg@3', ndcg_at_k(y_true, y_pred, 3))
# Out:
# precision@3 0.3333333333333333
# recall@3 0.3333333333333333
# ndcg@3 0.46927872602275644
