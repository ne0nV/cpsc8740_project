# %% [markdown]
# # 01 — Train Baselines

# %%
import pandas as pd
from src.models.baselines import build_popularity
from src.utils.config import DATA_DIR
df = pd.read_csv(DATA_DIR/'sample_interactions.csv')
pop = build_popularity(df)
pop.head()

# %%
from src.models.baselines import user_history
hist = user_history(df)
list(hist.items())[:3]
